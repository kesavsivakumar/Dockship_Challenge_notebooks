# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive
# Out:
# [Errno 2] No such file or directory: 'drive'
# /content/drive/My Drive

# %%
cd My Drive
# Out:
# [Errno 2] No such file or directory: 'My Drive'
# /content/drive/My Drive

# %%
#!wget -O "rethink_ux_text_recognition_hiring_challenge-dataset.zip" "https://dockship-job-models.s3.ap-south-1.amazonaws.com/7ef338b89224e00e2a30806715849c48?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIDOPTEUZ2LEOQEGQ%2F20201111%2Fap-south-1%2Fs3%2Faws4_request&X-Amz-Date=20201111T080235Z&X-Amz-Expires=1800&X-Amz-Signature=b645970219ed30bd9215f08b6cc5e789859cb05e39a1e411bdf10374b80b5d0d&X-Amz-SignedHeaders=host&response-content-disposition=attachment%3B%20filename%3D%22rethink_ux_text_recognition_hiring_challenge-dataset.zip%22"

# %%
#!unzip rethink_ux_text_recognition_hiring_challenge-dataset.zip -d TextRecognition

# %%
#!pip install pytesseract

# %%
'''!sudo apt-get update
# !sudo apt-get install libleptonica-dev 
# !sudo apt-get install tesseract-ocr tesseract-ocr-dev
# !sudo apt-get install libtesseract-dev'''
# Out:
# '!sudo apt-get update\n!sudo apt-get install libleptonica-dev \n!sudo apt-get install tesseract-ocr tesseract-ocr-dev\n!sudo apt-get install libtesseract-dev'

# %%
#!pip install tesseract
#!pip install tesseract-ocr
#!sudo apt install tesseract-ocr

# %%
import cv2
import re
import os
import pandas as pd
import numpy as np
import pytesseract

# %%
len(os.listdir('TextRecognition/TRAIN'))
# Out:
# 165480

# %%
df=pd.read_csv('TextRecognition/TRAIN.csv')

# %%
df
# Out:
#           FILENAME    VALUES
# 0       000000.jpg  KESSELER
# 1       000001.jpg     LUCAS
# 2       000002.jpg      ELYN
# 3       000003.jpg    ALONZO
# 4       000004.jpg      NINO
# ...            ...       ...
# 165475  165475.jpg       LIA
# 165476  165476.jpg    ADRIEN
# 165477  165477.jpg  MAZAURIC
# 165478  165478.jpg      THEO
# 165479  165479.jpg   BOLLACK
#
# [165480 rows x 2 columns]

# %%
images=[]

# %%
result=[]

# %%
count=1
for path in os.listdir('TextRecognition/TEST'):
  img=cv2.imread('TextRecognition/TEST/'+path)
  #print(img.shape)
  #img=cv2.resize(img,(256,256))
  #print(img.shape)
  gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
  gray, img_bin = cv2.threshold(gray,128,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
  gray = cv2.bitwise_not(img_bin)
  kernel = np.ones((2, 1), np.uint8)
  img = cv2.erode(gray, kernel, iterations=1)
  img = cv2.dilate(img, kernel, iterations=1)
  out_below = pytesseract.image_to_string(img)
  out_below=out_below.upper()
  ansi =re.compile(r'(\x9B|\x1B\[)[0-?]*[ -\/]*[@-~]')
  out_below=ansi.sub('', out_below)
  result.append([path,out_below])
  count=count+1
  print(count)
# Out:
# Streaming output truncated to the last 5000 lines.
# 15688
# 15689
# 15690
# 15691
# 15692
# 15693
# 15694
# 15695
# 15696
# 15697
# 15698
# 15699
# 15700
# 15701
# 15702
# 15703
# 15704
# 15705
# 15706
# 15707
# 15708
# 15709
# 15710
# 15711
# 15712
# 15713
# 15714
# 15715
# 15716
# 15717
# 15718
# 15719
# 15720
# 15721
# 15722
# 15723
# 15724
# 15725
# 15726
# 15727
# 15728
# 15729
# 15730
# 15731
# 15732
# 15733
# 15734
# 15735
# 15736
# 15737
# 15738
# 15739
# 15740
# 15741
# 15742
# 15743
# 15744
# 15745
# 15746
# 15747
# 15748
# 15749
# 15750
# 15751
# 15752
# 15753
# 15754
# 15755
# 15756
# 15757
# 15758
# 15759
# 15760
# 15761
# 15762
# 15763
# 15764
# 15765
# 15766
# 15767
# 15768
# 15769
# 15770
# 15771
# 15772
# 15773
# 15774
# 15775
# 15776
# 15777
# 15778
# 15779
# 15780
# 15781
# 15782
# 15783
# 15784
# 15785
# 15786
# 15787
# 15788
# 15789
# 15790
# 15791
# 15792
# 15793
# 15794
# 15795
# 15796
# 15797
# 15798
# 15799
# 15800
# 15801
# 15802
# 15803
# 15804
# 15805
# ...

# %%
result
# Out:
# [['005446.jpg', 'SOL ON A\n\x0c'],
#  ['002186.jpg', 'AL\n\nCRAS 2CN A\n\n \n\x0c'],
#  ['010764.jpg', ' \n\x0c'],
#  ['013195.jpg', 'AAD\n\x0c'],
#  ['009957.jpg', 'AE\n\x0c'],
#  ['017884.jpg', 'AME ELS\n\x0c'],
#  ['007077.jpg', ' \n\nATID\n\x0c'],
#  ['006139.jpg', 'ICON AA\n\x0c'],
#  ['019254.jpg', 'LTLOV\n\x0c'],
#  ['009869.jpg', 'RENOM :\nA) I? SO EA\n\x0c'],
#  ['003184.jpg', 'ATS AGUR-SEUGNET\n\x0c'],
#  ['014547.jpg', 'HY\n\nA\n\x0c'],
#  ['020401.jpg', 'NOM\nREEL\n\x0c'],
#  ['011249.jpg', '   \n\nIE)\nFONTENIELE\n\x0c'],
#  ['011807.jpg', 'A) EN\n\x0c'],
#  ['020408.jpg', 'EE I ANE\n\nMEL RIB ANMASSEY\n\n \n\x0c'],
#  ['007073.jpg', 'ON\nACK SE\n\x0c'],
#  ['016579.jpg', 'EE\n\x0c'],
#  ['012554.jpg', 'AND\n\nA KEN AE\n\x0c'],
#  ['019332.jpg', ' \n\x0c'],
#  ['018332.jpg', 'LA\n\x0c'],
#  ['000669.jpg', ' \n\nCT KT)\n\x0c'],
#  ['006976.jpg', 'VALE PYARE\n\x0c'],
#  ['015673.jpg', '\x0c'],
#  ['000672.jpg', 'LT\nMERE EY\n\x0c'],
#  ['011759.jpg', 'BLYZ) ABL\n\x0c'],
# ...

# %%
escapes = ''.join([chr(char) for char in range(1, 32)])
for i in range(len(result)):
  #result[i][1]=re.sub(r'[\x9B|\x1B]','',result[i][1])
  result[i][1] = result[i][1].translate( escapes)

# %%
for i in range(len(result)):
  result[i][1]=re.sub(r'\x0b','',result[i][1])
  #result[i][1] = result[i][1].translate( escapes)

# %%
for i in range(len(result)):
  result[i][1]=re.sub(r'\r','',result[i][1])
  #result[i][1] = result[i][1].translate( escapes)

# %%
for i in range(len(result)):
  result[i][1]=re.sub(r' ','',result[i][1])
  #result[i][1] = result[i][1].translate( escapes)

# %%
for i in range(len(result)):
  result[i][1]=re.sub(r'[:+-/*@()?<>;]','',result[i][1])
  #result[i][1] = result[i][1].translate( escapes)

# %%
result
# Out:
# [['005446.jpg', 'SOLONA'],
#  ['002186.jpg', 'ALCRAS2CNA'],
#  ['010764.jpg', ''],
#  ['013195.jpg', 'AAD'],
#  ['009957.jpg', 'AE'],
#  ['017884.jpg', 'AMEELS'],
#  ['007077.jpg', 'ATID'],
#  ['006139.jpg', 'ICONAA'],
#  ['019254.jpg', 'LTLOV'],
#  ['009869.jpg', 'RENOMAISOEA'],
#  ['003184.jpg', 'ATSAGURSEUGNET'],
#  ['014547.jpg', 'HYA'],
#  ['020401.jpg', 'NOMREEL'],
#  ['011249.jpg', 'IEFONTENIELE'],
#  ['011807.jpg', 'AEN'],
#  ['020408.jpg', 'EEIANEMELRIBANMASSEY'],
#  ['007073.jpg', 'ONACKSE'],
#  ['016579.jpg', 'EE'],
#  ['012554.jpg', 'ANDAKENAE'],
#  ['019332.jpg', ''],
#  ['018332.jpg', 'LA'],
#  ['000669.jpg', 'CTKT'],
#  ['006976.jpg', 'VALEPYARE'],
#  ['015673.jpg', ''],
#  ['000672.jpg', 'LTMEREEY'],
#  ['011759.jpg', 'BLYZABL'],
#  ['000699.jpg', 'RN'],
#  ['000226.jpg', 'BNESEALOEÉAWAY'],
#  ['015570.jpg', 'PERRAREE'],
#  ['000252.jpg', 'CSNW'],
#  ['012690.jpg', 'ARCAE'],
#  ['011647.jpg', 'RTEEES'],
#  ['011252.jpg', 'ARESONTOEA'],
#  ['006053.jpg', 'A'],
# ...

# %%
import pickle
fp=open('result.pkl','wb')
pickle.dump(result,fp)

# %%
df=pd.DataFrame(result,columns=['FILENAME','VALUES'])

# %%
df
# Out:
#          FILENAME          VALUES
# 0      005446.jpg          SOLONA
# 1      002186.jpg      ALCRAS2CNA
# 2      010764.jpg
# 3      013195.jpg             AAD
# 4      009957.jpg              AE
# ...           ...             ...
# 20680  000433.jpg  ELFATAANESAEAA
# 20681  007525.jpg      IARERVS4NI
# 20682  014382.jpg              AE
# 20683  015991.jpg          ANLEID
# 20684  018494.jpg
#
# [20685 rows x 2 columns]

# %%
df.to_csv('TRCoutput.csv',index=False)

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive'

# %%
ls
# Out:
# '10 m.pdf'
# '121003143_KESAV_KUMAR_J_S - Copy.docx'
#  16004897810889047015622904082522.jpg
#  2m
# '2m (1)'
#  2m_1.jpg
#  2m_2.jpg
#  accident_2009.csv
#  accident_2010.csv
#  accident_2012.csv
#  accident_2013.csv
#  all.zip
#  bayesnet/
# 'bda 2.pdf'
#  BDA-ABSTRACT.docx
# 'bda spider traps.pdf'
#  bdct.m
#  bdctmtx.m
#  BM3D.ipynb
#  butterfly_classification_ai_challenge-dataset.zip
# 'CamScanner 09-19-2020 09.37.58.pdf'
# 'CamScanner 10-29-2020 10.47.37.pdf'
# 'CamScanner 10-30-2020 14.42.44.pdf'
#  CBSD68/
#  Classroom/
# 'Colab Notebooks'/
#  cv_assignment.png
#  CVPR_CAPTURED_IMAGES/
#  CVPR_FRONTAL_FACE_DATASET/
#  CVPR_images.npy
#  DATA/
#  Dataset/
#  dequantize.m
# 'Ex_2B IPC using Message Queue.gdoc'
# 'Ex_2B IPC using Message Queue.pdf'
#  FoETrainingSets176/
# 'Getting started.pdf'
#  ibdct.m
#  im2vec.m
#  jpeg_qtable.m
#  jpeg_read.c
#  jpeg_read.dll
#  jpeg_read.m
#  jpeg_write.c
#  jpeg_write.dll
#  jpeg_write.m
#  log.csv
#  log.gsheet
#  model_best.pth
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive
# Out:
# /content/drive

# %%
cd My Drive
# Out:
# /content/drive/My Drive

# %%
ls
# Out:
# '10 m.pdf'
# '121003143_KESAV_KUMAR_J_S - Copy.docx'
#  16004897810889047015622904082522.jpg
#  2m
# '2m (1)'
#  2m_1.jpg
#  2m_2.jpg
#  accident_2009.csv
#  accident_2010.csv
#  accident_2012.csv
#  accident_2013.csv
#  all.zip
#  bayesnet/
# 'bda 2.pdf'
#  BDA-ABSTRACT.docx
# 'bda spider traps.pdf'
#  bdct.m
#  bdctmtx.m
#  BM3D.ipynb
#  butterfly_classification_ai_challenge-dataset.zip
# 'CamScanner 09-19-2020 09.37.58.pdf'
# 'CamScanner 10-29-2020 10.47.37.pdf'
# 'CamScanner 10-30-2020 14.42.44.pdf'
#  CBSD68/
#  Classroom/
# 'Colab Notebooks'/
#  cv_assignment.png
#  CVPR_CAPTURED_IMAGES/
#  CVPR_FRONTAL_FACE_DATASET/
#  CVPR_images.npy
#  DATA/
#  Dataset/
#  dequantize.m
# 'Ex_2B IPC using Message Queue.gdoc'
# 'Ex_2B IPC using Message Queue.pdf'
#  FoETrainingSets176/
# 'Getting started.pdf'
#  ibdct.m
#  im2vec.m
#  jpeg_qtable.m
#  jpeg_read.c
#  jpeg_read.dll
#  jpeg_read.m
#  jpeg_write.c
#  jpeg_write.dll
#  jpeg_write.m
#  log.csv
#  log.gsheet
#  model_best.pth
# ...

# %%
#!wget -O "rethink_ux_internship_challenge-dataset.zip" "https://dockship-job-models.s3.ap-south-1.amazonaws.com/6a7b824ced934c74d9f4a536eec46ebe?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIDOPTEUZ2LEOQEGQ%2F20201020%2Fap-south-1%2Fs3%2Faws4_request&X-Amz-Date=20201020T044228Z&X-Amz-Expires=1800&X-Amz-Signature=b042651ad31b49a885c18297792f98567e0d05e3a8bdf596a2874db915448003&X-Amz-SignedHeaders=host&response-content-disposition=attachment%3B%20filename%3D%22rethink_ux_internship_challenge-dataset.zip%22"

# %%
#!unzip  rethink_ux_internship_challenge-dataset.zip

# %% [markdown]
# Load Dataset

# %%
import cv2
import os

# %%
from keras.preprocessing import image as image_utils
from keras.applications.imagenet_utils import decode_predictions
from keras.applications.imagenet_utils import preprocess_input
from keras.applications import VGG16
import numpy as np
from numpy import array
from numpy import argmax
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping,ModelCheckpoint

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive'

# %%
dic={'buildings':0, 'glacier':1, 'street':2, 'forest':3, 'mountain':4, 'sea':5}

# %%
'''trainX=[]
trainY=[]
train_path=os.listdir(r'/content/drive/My Drive/TRAIN')'''
test_path=os.listdir(r'/content/drive/My Drive/TEST')

# %%
'''for label_dir in train_path:
  x=os.listdir(r'/content/drive/My Drive/TRAIN/'+label_dir+'/')
  for i in x:
    path='/content/drive/My Drive/TRAIN/'+label_dir+'/'+i
    img=cv2.imread(path)
    img=cv2.resize(img,(150,150))
    #print(img.shape)
    trainX.append(img)
    trainY.append(dic[label_dir])'''
# Out:
# "for label_dir in train_path:\n  x=os.listdir(r'/content/drive/My Drive/TRAIN/'+label_dir+'/')\n  for i in x:\n    path='/content/drive/My Drive/TRAIN/'+label_dir+'/'+i\n    img=cv2.imread(path)\n    img=cv2.resize(img,(150,150))\n    #print(img.shape)\n    trainX.append(img)\n    trainY.append(dic[label_dir])"

# %%
trainX=np.load('trainX.npy',allow_pickle=True)
trainY=np.load('trainY.npy',allow_pickle=True)

# %%
print(len(trainX) , len(trainY),trainX[0].shape)
# Out:
# 13625 13625 (150, 150, 3)

# %%
trainX.shape
# Out:
# (13625, 150, 150, 3)

# %%
'''np.save('trainX.npy',trainX)
np.save('trainY.npy',trainY)'''
# Out:
# "np.save('trainX.npy',trainX)\nnp.save('trainY.npy',trainY)"

# %%
trainX.shape
# Out:
# (13625, 150, 150, 3)

# %% [markdown]
# Preprocessing

# %%
'''for i in range(trainX.shape[0]):
    img = trainX[i]
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

    lab_planes = cv2.split(lab)

    clahe = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(16,16))

    lab_planes[0] = clahe.apply(lab_planes[0])

    lab = cv2.merge(lab_planes)

    img = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)  
    trainX[i]=img

print('Shape of train images: ', trainX[0].shape)'''
# Out:
# "for i in range(trainX.shape[0]):\n    img = trainX[i]\n    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)\n\n    lab_planes = cv2.split(lab)\n\n    clahe = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(16,16))\n\n    lab_planes[0] = clahe.apply(lab_planes[0])\n\n    lab = cv2.merge(lab_planes)\n\n    img = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)  \n    trainX[i]=img\n\nprint('Shape of train images: ', trainX[0].shape)"

# %%
trainX.shape
# Out:
# (13625, 150, 150, 3)

# %%
from keras.applications import ResNet50,VGG19
from keras.models import Model, Sequential
from keras import layers
# load model without classifier layers
model=Sequential()
model.add(VGG19(input_shape=(150,150,3),include_top=False,pooling='avg',weights='imagenet'))
#print(model._get_trainable_state())
# Set every layer to be non-trainable:
#for k,v in model._get_trainable_state().items():
    #k.trainable = False
#model.add(Flatten())
model.add(layers.Dense(1000, activation='relu', kernel_initializer='he_uniform'))
model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
#model.add(Dense(,activation='relu'))
model.add(layers.Dense(6,activation='softmax'))
# summarize
model.layers[0].trainable = False
model.summary()

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# ...
# 80142336/80134624 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# vgg19 (Functional)           (None, 512)               20024384
# _________________________________________________________________
# dense (Dense)                (None, 1000)              513000
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               128128
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 774
# ...
# Total params: 20,666,286
# Trainable params: 641,902
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
'''model = Sequential()
model.add(layers.Conv2D(filters=8,kernel_size=(3,3),input_shape=(150,150,3),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1)) 
    
model.add(layers.MaxPooling2D(pool_size=(2,2),strides=2)) 
    
model.add(layers.Conv2D(filters=16,kernel_size=(3,3),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1)) 

model.add(layers.MaxPooling2D(pool_size=(2,2),strides=2)) 

model.add(layers.Conv2D(filters=32,kernel_size=(3,3),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
model.add(layers.Conv2D(filters=32,kernel_size=(1,1),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
model.add(layers.Conv2D(filters=32,kernel_size=(3,3),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1)) 

model.add(layers.MaxPooling2D(pool_size=(2,2),strides=2)) 
    
model.add(layers.Conv2D(filters=64,kernel_size=(3,3),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
model.add(layers.Conv2D(filters=64,kernel_size=(1,1),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
model.add(layers.Conv2D(filters=64,kernel_size=(3,3),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1)) 

model.add(layers.MaxPooling2D(pool_size=(2,2),strides=2)) 

model.add(layers.Conv2D(filters=128,kernel_size=(3,3),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
model.add(layers.Conv2D(filters=128,kernel_size=(1,1),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
model.add(layers.Conv2D(filters=128,kernel_size=(3,3),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
 
model.add(layers.MaxPooling2D(pool_size=(2,2),strides=2))
 
model.add(layers.Conv2D(filters=256,kernel_size=(3,3),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
model.add(layers.Conv2D(filters=256,kernel_size=(1,1),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
model.add(layers.Conv2D(filters=256,kernel_size=(3,3),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
 
model.add(layers.Conv2D(filters=128,kernel_size=(3,3),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
 
model.add(layers.Conv2D(filters=256,kernel_size=(3,3),strides=1,padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.LeakyReLU(alpha=0.1))
 
model.add(layers.Conv2D(filters=3,kernel_size=(3,3),strides=1,padding='same'))
 
model.add(layers.Flatten())

#model.add(layers.Dense(64, activation='relu')) 
model.add(layers.Dense(6, activation='softmax'))
model.summary()

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])'''
# Out:
# "model = Sequential()\nmodel.add(layers.Conv2D(filters=8,kernel_size=(3,3),input_shape=(150,150,3),strides=1,padding='same'))\nmodel.add(layers.BatchNormalization())\nmodel.add(layers.LeakyReLU(alpha=0.1)) \n    \nmodel.add(layers.MaxPooling2D(pool_size=(2,2),strides=2)) \n    \nmodel.add(layers.Conv2D(filters=16,kernel_size=(3,3),strides=1,padding='same'))\nmodel.add(layers.BatchNormalization())\nmodel.add(layers.LeakyReLU(alpha=0.1)) \n\nmodel.add(layers.MaxPooling2D(pool_size=(2,2),strides=2)) \n\nmodel.add(layers.Conv2D(filters=32,kernel_size=(3,3),strides=1,padding='same'))\nmodel.add(layers.BatchNormalization())\nmodel.add(layers.LeakyReLU(alpha=0.1))\nmodel.add(layers.Conv2D(filters=32,kernel_size=(1,1),strides=1,padding='same'))\nmodel.add(layers.BatchNormalization())\nmodel.add(layers.LeakyReLU(alpha=0.1))\nmodel.add(layers.Conv2D(filters=32,kernel_size=(3,3),strides=1,padding='same'))\nmodel.add(layers.BatchNormalization())\nmodel.add(layers.LeakyReLU(alpha=0.1)) \n\nmodel.
# ...

# %%
trainY=np.array(trainY)
encoded_y=to_categorical(trainY)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(trainX, encoded_y, test_size=0.05, random_state=42)

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=64)
mc = ModelCheckpoint(r'rethink_UX.h5', monitor='val_accuracy',mode='max', verbose=1, save_best_only=True)
 # fit model
history = model.fit( X_train,y_train,validation_data=(X_val,y_val),batch_size=128,epochs=100, verbose=1,callbacks=[es,mc])
# Out:
# Epoch 1/100
# 102/102 [==============================] - ETA: 0s - loss: 0.8085 - accuracy: 0.8466
# Epoch 00001: val_accuracy improved from -inf to 0.86950, saving model to rethink_UX.h5
# 102/102 [==============================] - 3337s 33s/step - loss: 0.8085 - accuracy: 0.8466 - val_loss: 0.3886 - val_accuracy: 0.8695
# Epoch 2/100
# 102/102 [==============================] - ETA: 0s - loss: 0.2282 - accuracy: 0.9192
# Epoch 00002: val_accuracy improved from 0.86950 to 0.88416, saving model to rethink_UX.h5
# 102/102 [==============================] - 3332s 33s/step - loss: 0.2282 - accuracy: 0.9192 - val_loss: 0.4056 - val_accuracy: 0.8842
# Epoch 3/100
# 102/102 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9404
# Epoch 00003: val_accuracy improved from 0.88416 to 0.88856, saving model to rethink_UX.h5
# 102/102 [==============================] - 3338s 33s/step - loss: 0.1576 - accuracy: 0.9404 - val_loss: 0.4051 - val_accuracy: 0.8886
# Epoch 4/100
# ...

# %% [markdown]
# ROUGH WORK

# %%
# define example
data = [1, 3, 2, 0, 3, 2, 2, 1, 0, 1]
data = array(data)
print(data)
# one hot encode
encoded = to_categorical(data)
print(encoded)
# invert encoding
inverted = argmax(encoded[0])
print(inverted)

# %%
testX=[]
file_name=[]
x=os.listdir(r'/content/drive/My Drive/TEST/')
for i in x:
  path='/content/drive/My Drive/TEST/'+i
  #print(path)
  img=cv2.imread(path)
  #print(img)
  img=cv2.resize(img,(150,150))
  #print(img.shape)
  testX.append(img)
  file_name.append(i)

# %%
testX=np.array(testX)

# %%
testX.shape

# %%
np.save('testX.npy',testX)

# %%
X_test=np.load('testX.npy',allow_pickle=True)

# %%
X_test.shape

# %%
'''for i in range(X_test.shape[0]):
    img = X_test[i]
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

    lab_planes = cv2.split(lab)

    clahe = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(16,16))

    lab_planes[0] = clahe.apply(lab_planes[0])

    lab = cv2.merge(lab_planes)

    img = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)  
    X_test[i]=img

print('Shape of train images: ', X_test[0].shape)'''

# %%
model.load_weights(r'rethink_UX.h5')

# %%
y_pred_inverted=[]
for i in range(0,3409):
  x=X_test[i]
  x=x[np.newaxis,:,:,:]
  y_pred=model.predict(x)
  y_pred_inverted.append(argmax(y_pred))

# %%
print(y_pred.shape)

# %%
y_pred_inverted

# %%
dic2={0:'buildings', 1:'glacier', 2:'street', 3:'forest', 4:'mountain', 5:'sea'}

# %%
pred_labels=[]
for i in y_pred_inverted:
  pred_labels.append(dic2[i])

# %%
pred_labels

# %%
file_name

# %%
final_dict={'Filename':file_name,'Labels':pred_labels}

# %%
import pandas as pd

# %%
csvlist=[]
for i in range(3409):
  csvlist.append([file_name[i],pred_labels[i]])

# %%
csvlist

# %%
df=pd.DataFrame(csvlist,columns=['Filename','Labels'])

# %%
df

# %%
df.to_csv('output.csv',index=False)
